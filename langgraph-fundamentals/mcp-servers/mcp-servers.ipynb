# %% [markdown]
# ### MCP Servers

# %%
from mcp.server.fastmcp import FastMCP

mcp = FastMCP("Math")

@mcp.tool()
def add(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b

@mcp.tool()
def subtract(a: int, b: int) -> int:
    """Subtract two numbers."""
    return a - b

@mcp.tool()
def multiply(a: int, b: int) -> int:
    """Multiply two numbers."""
    return a * b

# %% [markdown]
# ### The transport="stdio" argument tells the server to
# - use standard in/out to recieve and respond the tool function call

# %%
if __name__ == "__main__":
    mcp.run(transport="stdio")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 if __name__ == "__main__":
# ----> 2     mcp.run(transport="stdio")
#
# File c:\Users\anupa\OneDrive\Documents\OneDrive\Desktop\aents\langproject\.venv\Lib\site-packages\mcp\server\fastmcp\server.py:296, in FastMCP.run(self, transport, mount_path)
#     294 match transport:
#     295     case "stdio":
# --> 296         anyio.run(self.run_stdio_async)
#     297     case "sse":  # pragma: no cover
#     298         anyio.run(lambda: self.run_sse_async(mount_path))
#
# File c:\Users\anupa\OneDrive\Documents\OneDrive\Desktop\aents\langproject\.venv\Lib\site-packages\anyio\_core\_eventloop.py:62, in run(func, backend, backend_options, *args)
#      44 """
#      45 Run the given coroutine function in an asynchronous event loop.
#      46
#    (...)     59
#      60 """
#      61 if asynclib_name := current_async_library():
# ---> 62     raise RuntimeError(f"Already running {asynclib_name} in this thread")
#      64 try:
#      65     async_backend = get_async_backend(backend)
#
# RuntimeError: Already running asyncio in this thread

# %% [markdown]
# ### 2:10:00
